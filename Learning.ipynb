# %% [markdown]
# <a href="https://colab.research.google.com/github/aydinkaraa/Track/blob/master/Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(0)
points = 500
X = np.linspace(-3, 3, points)
y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)

plt.scatter(X, y)

# %%
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _get_default_graph()
#      65     try:
# ---> 66         return tf.get_default_graph()
#      67     except AttributeError:
#
# AttributeError: module 'tensorflow' has no attribute 'get_default_graph'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-3ad19084f971> in <module>()
# ----> 1 model = Sequential()
#       2 model.add(Dense(50, activation='sigmoid', input_dim=1))
#       3 model.add(Dense(30, activation='sigmoid'))
#       4 model.add(Dense(1))
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/sequential.py in __init__(self, layers, name)
#      86
#      87     def __init__(self, layers=None, name=None):
# ---> 88         super(Sequential, self).__init__(name=name)
#      89         self._build_input_shape = None
#      90
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in __init__(self, *args, **kwargs)
#      95         else:
#      96             # Subclassed network
# ---> 97             self._init_subclassed_network(**kwargs)
#      98
#      99     def _base_init(self, name=None, trainable=True, dtype=None):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in _init_subclassed_network(self, name, **kwargs)
#     298
#     299     def _init_subclassed_network(self, name=None, **kwargs):
# --> 300         self._base_init(name=name, **kwargs)
#     301         self._is_graph_network = False
#     302         self._expects_training_arg = has_arg(self.call, 'training')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in _base_init(self, name, trainable, dtype)
#     108         if not name:
#     109             prefix = self.__class__.__name__.lower()
# --> 110             name = prefix + '_' + str(K.get_uid(prefix))
#     111         self.name = name
#     112
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in get_uid(prefix)
#      84     """
#      85     global _GRAPH_UID_DICTS
# ---> 86     graph = _get_default_graph()
#      87     if graph not in _GRAPH_UID_DICTS:
#      88         _GRAPH_UID_DICTS[graph] = defaultdict(int)
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _get_default_graph()
#      67     except AttributeError:
#      68         raise RuntimeError(
# ---> 69             'It looks like you are trying to use '
#      70             'a version of multi-backend Keras that '
#      71             'does not support TensorFlow 2.0. We recommend '
#
# RuntimeError: It looks like you are trying to use a version of multi-backend Keras that does not support TensorFlow 2.0. We recommend using `tf.keras`, or alternatively, downgrading to TensorFlow 1.14.

# %%
adam = Adam(lr=0.01)
model.compile(loss='mse', optimizer=adam)
model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 0s 476us/step - loss: 0.1059
# Epoch 2/50
# 500/500 [==============================] - 0s 99us/step - loss: 0.1012
# Epoch 3/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.1031
# Epoch 4/50
# 500/500 [==============================] - 0s 99us/step - loss: 0.0995
# Epoch 5/50
# 500/500 [==============================] - 0s 103us/step - loss: 0.1018
# Epoch 6/50
# 500/500 [==============================] - 0s 99us/step - loss: 0.1007
# Epoch 7/50
# 500/500 [==============================] - 0s 134us/step - loss: 0.0998
# Epoch 8/50
# 500/500 [==============================] - 0s 99us/step - loss: 0.1033
# Epoch 9/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.1017
# Epoch 10/50
# 500/500 [==============================] - 0s 102us/step - loss: 0.0946
# Epoch 11/50
# 500/500 [==============================] - 0s 108us/step - loss: 0.0983
# Epoch 12/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.1048
# Epoch 13/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.1055
# Epoch 14/50
# 500/500 [==============================] - 0s 101us/step - loss: 0.0951
# Epoch 15/50
# 500/500 [==============================] - 0s 109us/step - loss: 0.0974
# Epoch 16/50
# 500/500 [==============================] - 0s 107us/step - loss: 0.1079
# Epoch 17/50
# 500/500 [==============================] - 0s 101us/step - loss: 0.1165
# Epoch 18/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.1124
# Epoch 19/50
# 500/500 [==============================] - 0s 104us/step - loss: 0.1000
# Epoch 20/50
# 500/500 [==============================] - 0s 103us/step - loss: 0.1015
# Epoch 21/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.0981
# Epoch 22/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.0946
# Epoch 23/50
# 500/500 [==============================] - 0s 96us/step - loss: 0.0963
# Epoch 24/50
# 500/500 [==============================] - 0s 96us/step - loss: 0.0977
# Epoch 25/50
# 500/500 [==============================] - 0s 107us/step - loss: 0.1020
# Epoch 26/50
# 500/500 [==============================] - 0s 119us/step - loss: 0.0962
# Epoch 27/50
# 500/500 [==============================] - 0s 107us/step - loss: 0.0988
# Epoch 28/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.0956
# Epoch 29/50
# 500/500 [==============================] - 0s 104us/step - loss: 0.0959
# Epoch 30/50
# 500/500 [==============================] - 0s 106us/step - loss: 0.0993
# Epoch 31/50
# 500/500 [==============================] - 0s 103us/step - loss: 0.0951
# Epoch 32/50
# 500/500 [==============================] - 0s 96us/step - loss: 0.0978
# Epoch 33/50
# 500/500 [==============================] - 0s 99us/step - loss: 0.0947
# Epoch 34/50
# 500/500 [==============================] - 0s 97us/step - loss: 0.0913
# Epoch 35/50
# 500/500 [==============================] - 0s 111us/step - loss: 0.0994
# Epoch 36/50
# 500/500 [==============================] - 0s 98us/step - loss: 0.0967
# Epoch 37/50
# 500/500 [==============================] - 0s 98us/step - loss: 0.0988
# Epoch 38/50
# 500/500 [==============================] - 0s 99us/step - loss: 0.1069
# Epoch 39/50
# 500/500 [==============================] - 0s 101us/step - loss: 0.0951
# Epoch 40/50
# 500/500 [==============================] - 0s 132us/step - loss: 0.0985
# Epoch 41/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.0962
# Epoch 42/50
# 500/500 [==============================] - 0s 98us/step - loss: 0.0949
# Epoch 43/50
# 500/500 [==============================] - 0s 98us/step - loss: 0.0939
# Epoch 44/50
# 500/500 [==============================] - 0s 97us/step - loss: 0.0960
# Epoch 45/50
# 500/500 [==============================] - 0s 101us/step - loss: 0.1042
# Epoch 46/50
# 500/500 [==============================] - 0s 138us/step - loss: 0.1032
# Epoch 47/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.0989
# Epoch 48/50
# 500/500 [==============================] - 0s 100us/step - loss: 0.1027
# Epoch 49/50
# 500/500 [==============================] - 0s 108us/step - loss: 0.0968
# Epoch 50/50
# 500/500 [==============================] - 0s 104us/step - loss: 0.0939

# %%
predictions = model.predict(X)
plt.scatter(X, y)
plt.plot(X, predictions, 'ro')
plt.show()
